# %%
import pandas as pd
df=pd.read_csv('C:/Users/DELL/Desktop/ETL Proj/perfectcleaned.csv')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head(10)
# Out:
#      Company_Serve tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      VeriFoneInc  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1      VeriFoneInc  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2      VeriFoneInc  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3  Creative Mobile  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4      VeriFoneInc  2023-01-01 00:10:29   2023-01-01 00:21:19
# 5      VeriFoneInc  2023-01-01 00:50:34   2023-01-01 01:02:52
# 6      VeriFoneInc  2023-01-01 00:09:22   2023-01-01 00:19:49
# 7      VeriFoneInc  2023-01-01 00:27:12   2023-01-01 00:49:56
# 8      VeriFoneInc  2023-01-01 00:21:44   2023-01-01 00:36:40
# 9      VeriFoneInc  2023-01-01 00:39:42   2023-01-01 00:50:36
#
#    passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# 0              1.0           0.97         1.0           161           141
# 1              1.0           1.10         1.0            43           237
# ...

# %%
#Histogram for trip distance

plt.figure(figsize=(18,6)) # creates plotcanvas of 10x6 size
plt.title('Dist of Trip distance')
sns.histplot(df['trip_distance'],bins=50,kde=True)
plt.xlabel('Trip distance (miles)')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram for fare amount
plt.figure(figsize=(10,6))
plt.title('Distribution of Fare amount')
sns.histplot(df['fare_amount'],bins=50, kde=True)
plt.xlabel('Fare Amount in $')
plt.ylabel('Frequency')
plt.show()

# %%
#plot for each individual payment description 
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='PaymentDesc',palette='Set2')
plt.title('Payment Method Distribution')  # Adds title
plt.xlabel('Payment Type')               # X-axis label
plt.ylabel('Number of Trips')            # Y-axis label
plt.xticks(rotation=-45)                  # Rotate x-axis labels for readability
#plt.ytick()
plt.show()                               # Show the plot
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18924\3893461545.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='PaymentDesc',palette='Set2')

# %%
#countplot for trip type
plt.figure(figsize=(5,5))
sns.countplot(data=df,x='trip_type',palette='Set2')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18924\550878574.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='trip_type',palette='Set2')
# <Axes: xlabel='trip_type', ylabel='count'>

# %%
df['trip_distance'].max()
# Out:
# np.float64(62359.52)

# %%
df
# Out:
#            Company_Serve tpep_pickup_datetime tpep_dropoff_datetime  \
# 0            VeriFoneInc  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1            VeriFoneInc  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2            VeriFoneInc  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3        Creative Mobile  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4            VeriFoneInc  2023-01-01 00:10:29   2023-01-01 00:21:19
# ...                  ...                  ...                   ...
# 2910174  Creative Mobile  2023-01-31 23:00:19   2023-02-01 00:08:33
# 2910175      VeriFoneInc  2023-01-31 23:14:38   2023-01-31 23:25:30
# 2910176      VeriFoneInc  2023-01-31 23:44:51   2023-01-31 23:58:45
# 2910177  Creative Mobile  2023-01-31 23:45:00   2023-01-31 23:55:46
# 2910178      VeriFoneInc  2023-01-31 23:22:47   2023-01-31 23:26:24
#
#          passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                    1.0           0.97         1.0           161
# ...

# %%
df=df[df['trip_distance'] <= 100]

# %%
#creating a box plot for detecting outliers in trip_distance column
plt.figure(figsize=(10,18))
plt.title('Box plot Distribution')
#plt.ytick()
plt.ylabel('Frequency')
sns.boxplot(x=df['trip_distance'],color='Blue',palette='Set2')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18924\3477141076.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['trip_distance'],color='Blue',palette='Set2')

# %%
df['fare_amount']
# Out:
# 0           9.3
# 1           7.9
# 2          14.9
# 3          12.1
# 4          11.4
#            ...
# 2910174    50.5
# 2910175    15.6
# 2910176    16.3
# 2910177    17.7
# 2910178     5.8
# Name: fare_amount, Length: 2910170, dtype: float64

# %%
'''#box plot of PaymentDesc vs Total amount
plt.figure(figsize=(10,10))
plt.title('PaymentDesc vs Total amount')
sns.countplot(data=df ,x='PaymentDesc',palette='Set2')
plt.xlabel('Payment Type')
plt.ylabel('Total Amount')
plt.show()'''


plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='PaymentDesc', y='total_amount', palette='Set3')
plt.title('Total Fare by Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Total Fare ($)')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18924\2438302992.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='PaymentDesc', y='total_amount', palette='Set3')

# %%
plt.figure(figsize=(12,12))  
sns.scatterplot(data=df, x='trip_distance', y='total_amount', alpha=0.5)  
plt.title('Trip Distance vs Total Amount')  
plt.xlabel('Trip Distances (miles)')       
plt.ylabel('Total Fare Amount ($)')      
plt.grid(True) 
plt.show()

# %%
df= df[df['total_amount'] <= 250]

# %%
plt.figure(figsize=(12,12))  
sns.scatterplot(data=df, x='trip_distance', y='total_amount', alpha=0.5)  
plt.title('Trip Distance vs Total Amount')  
plt.xlabel('Trip Distances (miles)')       
plt.ylabel('Total Fare Amount ($)')      
plt.grid(True) 
plt.show()

# %%
df
# Out:
#            Company_Serve tpep_pickup_datetime tpep_dropoff_datetime  \
# 0            VeriFoneInc  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1            VeriFoneInc  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2            VeriFoneInc  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3        Creative Mobile  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4            VeriFoneInc  2023-01-01 00:10:29   2023-01-01 00:21:19
# ...                  ...                  ...                   ...
# 2910174  Creative Mobile  2023-01-31 23:00:19   2023-02-01 00:08:33
# 2910175      VeriFoneInc  2023-01-31 23:14:38   2023-01-31 23:25:30
# 2910176      VeriFoneInc  2023-01-31 23:44:51   2023-01-31 23:58:45
# 2910177  Creative Mobile  2023-01-31 23:45:00   2023-01-31 23:55:46
# 2910178      VeriFoneInc  2023-01-31 23:22:47   2023-01-31 23:26:24
#
#          passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                    1.0           0.97         1.0           161
# ...

# %%
df[['trip_duration','tpep_pickup_datetime','tpep_dropoff_datetime']].head()
# Out:
#    trip_duration tpep_pickup_datetime tpep_dropoff_datetime
# 0           8.43  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1           6.32  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2          12.75  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3           9.62  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4          10.83  2023-01-01 00:10:29   2023-01-01 00:21:19

# %%
df['total_amount'].mean()
# Out:
# np.float64(26.892702869224966)

# %%
df['trip_distance'].mean()
# Out:
# np.float64(3.2961494407902983)

# %%
#df['avg_fare']=df['avg_fare'].apply(lambda x:'within avg fare' if x<=[df['total_amount'].mean()] / [df['trip_distance'].mean()]  else 'out of avg fare price')

df['spenton_fare']=df['total_amount']/ df['trip_distance']

# %%
df[['spenton_fare','total_amount','trip_distance']]
# Out:
#          spenton_fare  total_amount  trip_distance
# 0           14.742268         14.30           0.97
# 1           15.363636         16.90           1.10
# 2           13.904382         34.90           2.51
# 3           10.973684         20.85           1.90
# 4           13.762238         19.68           1.43
# ...               ...           ...            ...
# 2910174      3.741007         52.00          13.90
# 2910175      6.706231         22.60           3.37
# 2910176      8.146853         23.30           2.86
# 2910177      6.631579         25.20           3.80
# 2910178     18.000000         10.80           0.60
#
# [2910089 rows x 3 columns]

# %%
df.head(10)
# Out:
#      Company_Serve tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      VeriFoneInc  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1      VeriFoneInc  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2      VeriFoneInc  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3  Creative Mobile  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4      VeriFoneInc  2023-01-01 00:10:29   2023-01-01 00:21:19
# 5      VeriFoneInc  2023-01-01 00:50:34   2023-01-01 01:02:52
# 6      VeriFoneInc  2023-01-01 00:09:22   2023-01-01 00:19:49
# 7      VeriFoneInc  2023-01-01 00:27:12   2023-01-01 00:49:56
# 8      VeriFoneInc  2023-01-01 00:21:44   2023-01-01 00:36:40
# 9      VeriFoneInc  2023-01-01 00:39:42   2023-01-01 00:50:36
#
#    passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# 0              1.0           0.97         1.0           161           141
# 1              1.0           1.10         1.0            43           237
# ...

# %%
df.columns
# Out:
# Index(['Company_Serve', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge', 'airport_fee', 'drop_year', 'trip_duration',
#        'short_distance', 'total_taxes', 'BoroughPickup', 'PickupZone',
#        'PickupServiceZone', 'BoroughDropoff', 'DropoffZone',
#        'DropoffServiceZone', 'RateCodeDesc', 'PaymentDesc', 'trip_type',
#        'spenton_fare'],
#       dtype='object')

# %%
df.rename(columns={'spenton_fare':'Fare_per_mile'},inplace=True)

# %%
df.head(10)
# Out:
#      Company_Serve tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      VeriFoneInc  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1      VeriFoneInc  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2      VeriFoneInc  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3  Creative Mobile  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4      VeriFoneInc  2023-01-01 00:10:29   2023-01-01 00:21:19
# 5      VeriFoneInc  2023-01-01 00:50:34   2023-01-01 01:02:52
# 6      VeriFoneInc  2023-01-01 00:09:22   2023-01-01 00:19:49
# 7      VeriFoneInc  2023-01-01 00:27:12   2023-01-01 00:49:56
# 8      VeriFoneInc  2023-01-01 00:21:44   2023-01-01 00:36:40
# 9      VeriFoneInc  2023-01-01 00:39:42   2023-01-01 00:50:36
#
#    passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# 0              1.0           0.97         1.0           161           141
# 1              1.0           1.10         1.0            43           237
# ...

# %%
df = df[df['trip_distance'] > 0]

# %%
df = df[df['total_amount'] > 0]

# %%
df = df[df['fare_amount'] > 0]

# %%
df = df[(df['passenger_count'] > 0)]

# %%
df = df[(df['trip_duration'] > 0) & (df['trip_duration'] < 7200)]  # Keep trips less than 2 hrs

# %%
df.columns
# Out:
# Index(['Company_Serve', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge', 'airport_fee', 'drop_year', 'trip_duration',
#        'short_distance', 'total_taxes', 'BoroughPickup', 'PickupZone',
#        'PickupServiceZone', 'BoroughDropoff', 'DropoffZone',
#        'DropoffServiceZone', 'RateCodeDesc', 'PaymentDesc', 'trip_type',
#        'Fare_per_mile'],
#       dtype='object')

# %%
for col in ['Company_Serve', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
       'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
       'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
       'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
       'congestion_surcharge', 'airport_fee', 'drop_year', 'trip_duration',
       'short_distance', 'total_taxes', 'BoroughPickup', 'PickupZone',
       'PickupServiceZone', 'BoroughDropoff', 'DropoffZone',
       'DropoffServiceZone', 'RateCodeDesc', 'PaymentDesc', 'trip_type',
       'Fare_per_mile']:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print("-" * 40)
# Out:
# Unique values in 'Company_Serve':
# ['VeriFoneInc' 'Creative Mobile']
# ----------------------------------------
# Unique values in 'tpep_pickup_datetime':
# ['2023-01-01 00:32:10' '2023-01-01 00:55:08' '2023-01-01 00:25:04' ...
#  '2023-01-31 23:21:46' '2023-01-31 23:00:19' '2023-01-31 23:44:51']
# ----------------------------------------
# Unique values in 'tpep_dropoff_datetime':
# ['2023-01-01 00:40:36' '2023-01-01 01:01:27' '2023-01-01 00:37:49' ...
#  '2023-02-01 00:08:33' '2023-01-31 23:25:30' '2023-01-31 23:58:45']
# ----------------------------------------
# Unique values in 'passenger_count':
# [1. 2. 3. 4. 5. 6. 8. 7.]
# ----------------------------------------
# Unique values in 'trip_distance':
# [ 0.97  1.1   2.51 ... 30.42 30.68 28.78]
# ----------------------------------------
# Unique values in 'RatecodeID':
# [ 1.  2. 99.  5.  4.  3.  6.]
# ----------------------------------------
# Unique values in 'PULocationID':
# ...

# %%
sns.scatterplot(
    data=df,
    x='trip_distance',
    y='Fare_per_mile',
    alpha=0.3
)
# Out:
# <Axes: xlabel='trip_distance', ylabel='Fare_per_mile'>

# %%
numeric_df = df[['trip_distance', 'Fare_per_mile']]

# Plot
sns.pairplot(data=numeric_df, height=3)
plt.suptitle("Pairplot: Trip Distance vs Fare per Mile", y=1.02)
plt.show()

# %%
#plotting pie chart of distribution of passenger count
trip_counts=df['passenger_count'].value_counts()
plt.figure(figsize=(10,10))
plt.title('Distribution of passenger count')
plt.pie(trip_counts,labels=trip_counts.index,startangle=140)
plt.show()

# %%
#to create a heatmap we need a create a correlation matrix which we pass in the heatmap
corr=df[['total_amount','Fare_per_mile','trip_distance']].corr()
plt.title('heatmap')
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.savefig('heat.png')
plt.show()

# %%
df.columns
# Out:
# Index(['Company_Serve', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge', 'airport_fee', 'drop_year', 'trip_duration',
#        'short_distance', 'total_taxes', 'BoroughPickup', 'PickupZone',
#        'PickupServiceZone', 'BoroughDropoff', 'DropoffZone',
#        'DropoffServiceZone', 'RateCodeDesc', 'PaymentDesc', 'trip_type',
#        'Fare_per_mile'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#making sure that the tpep_pickup_datetime is datetime data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2829536 entries, 0 to 2910178
# Data columns (total 32 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Company_Serve          object
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   PULocationID           int64
#  7   DOLocationID           int64
#  8   payment_type           int64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  congestion_surcharge   float64
#  17  airport_fee            float64
#  18  drop_year              int64
#  19  trip_duration          float64
#  20  short_distance         int64
# ...

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2829536 entries, 0 to 2910178
# Data columns (total 32 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Company_Serve          object
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   PULocationID           int64
#  7   DOLocationID           int64
#  8   payment_type           int64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  congestion_surcharge   float64
#  17  airport_fee            float64
#  18  drop_year              int64
#  19  trip_duration          float64
#  20  short_distance         int64
# ...

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2829536 entries, 0 to 2829535
# Data columns (total 32 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   tpep_pickup_datetime   datetime64[ns]
#  1   Company_Serve          object
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   PULocationID           int64
#  7   DOLocationID           int64
#  8   payment_type           int64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  congestion_surcharge   float64
#  17  airport_fee            float64
#  18  drop_year              int64
#  19  trip_duration          float64
#  20  short_distance         int64
# ...

# %%
'''df.set_index('tpep_pickup_datetime', inplace=True)

# Step 2: Resample hourly and compute mean
avghourly_fare_per_mile = df['Fare_per_mile'].resample('H').mean()

# Step 3 (optional): Plot the result
plt.figure(figsize=(12,6))
plt.plot(avghourly_fare_per_mile, color='purple')
plt.title('Hourly Average Fare per Mile')
plt.xlabel('Hour')
plt.ylabel('Fare per Mile')
plt.grid(True)
plt.tight_layout()
plt.show()'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7656\892236628.py in ?()
# ----> 1 df.set_index('tpep_pickup_datetime', inplace=True)
#       2
#       3 # Step 2: Resample hourly and compute mean
#       4 avghourly_fare_per_mile = df['Fare_per_mile'].resample('H').mean()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6125                     if not found:
#    6126                         missing.append(col)
#    6127
#    6128         if missing:
# -> 6129             raise KeyError(f"None of {missing} are in the columns")
#    6130
#    6131         if inplace:
#    6132             frame = self
#
# KeyError: "None of ['tpep_pickup_datetime'] are in the columns"

# %%
# !pip install sqlalchemy
# !pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
import pandas as pd

username='postgres'
password='Spiro1601'
host='localhost'
port='5432'
database='proj_db'

# %%
engine=create_engine(f'postgresql://postgres:Spiro1601@localhost:5432/proj_db')

# %%
df.to_sql('perfectcleaned',engine,if_exists='replace',index=False)

# %%
df.to_csv('FinalCleaned.csv',index=False)

# %%
import psycopg2 as psy

# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname='proj_db',
    user='postgres',
    password='Spiro1601',
    host='localhost',
    port='5432'
)
cur = conn.cursor()

# Create table (if not exists)
cur.execute("""
    CREATE TABLE IF NOT EXISTS nyc_cleaned (
        tpep_pickup_datetime TIMESTAMP,
        Company_Serve TEXT,
        tpep_dropoff_datetime TIMESTAMP,
        passenger_count FLOAT,
        trip_distance FLOAT,
        RatecodeID FLOAT,
        PULocationID INT,
        DOLocationID INT,
        payment_type INT,
        fare_amount FLOAT,
        extra FLOAT,
        mta_tax FLOAT,
        tip_amount FLOAT,
        tolls_amount FLOAT,
        improvement_surcharge FLOAT,
        total_amount FLOAT,
        congestion_surcharge FLOAT,
        airport_fee FLOAT,
        drop_year INT,
        trip_duration FLOAT,
        short_distance BOOLEAN,
        total_taxes FLOAT,
        BoroughPickup TEXT,
        PickupZone TEXT,
        PickupServiceZone TEXT,
        BoroughDropoff TEXT,
        DropoffZone TEXT,
        DropoffServiceZone TEXT,
        RateCodeDesc TEXT,
        PaymentDesc TEXT,
        trip_type TEXT,
        Fare_per_mile FLOAT
    )
""")

# Load CSV into PostgreSQL (SUPER FAST)
with open("FinalCleaned.csv", "r", encoding="utf-8") as f:
    next(f)  # Skip header row
    cur.copy_expert("COPY nyc_cleaned FROM STDIN WITH CSV", f)

conn.commit()
cur.close()
conn.close()

print("✅ Data loaded successfully with COPY!")
# Out:
# ✅ Data loaded successfully with COPY!

# %%
df['DropoffZone'].unique()
# Out:
# array(['Lenox Hill West', 'Upper East Side South',
#        'Upper West Side North', 'East Village', 'Kips Bay',
#        'Lincoln Square West', 'Riverdale/North Riverdale/Fieldston',
#        'Upper East Side North', 'Gramercy', 'East Chelsea',
#        'Brooklyn Heights', 'Crown Heights North',
#        'Penn Station/Madison Sq West', 'Clinton East',
#        'Williamsburg (North Side)', 'Upper West Side South',
#        'Sutton Place/Turtle Bay North', 'Hamilton Heights',
#        'Midtown Center', 'Midtown South', 'Financial District North',
#        'Two Bridges/Seward Park', 'Yorkville East', 'East Harlem South',
#        'Bushwick North', 'Yorkville West', 'Lenox Hill East',
#        'West Chelsea/Hudson Yards', 'TriBeCa/Civic Center', 'Murray Hill',
#        'Central Park', 'UN/Turtle Bay South', 'Alphabet City',
#        'Midtown East', 'Stuy Town/Peter Cooper Village',
#        'Long Island City/Hunters Point', 'Hudson Sq', 'Bloomingdale',
# ...
